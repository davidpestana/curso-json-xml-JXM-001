// %% [markdown]
// # 🧱 LAB: Ficha de Producto en XML
//
// Vamos a crear nuestra **primera ficha técnica** para el ecommerce.
//
// 📌 Objetivos:
// - Crear un XML bien formado
// - Añadir información clave del producto
// - Leerlo y validarlo con JavaScript y DOMParser
//
// ⏱️ Tiempo estimado: **20-30 minutos**

// %% [markdown]
// ---
// ## 🥇 Paso 1 — Crear el XML
// Define un XML básico del producto con nodos:
// - `<producto>` raíz
// - `<nombre>`
// - `<precio>`
// - `<stock>`

// %%
// ✍️ Escribe aquí tu XML como string template
const xmlProducto = `<catalogo id="catalogo1"><producto id="1"><precio>11</precio><nombre>Webcam</nombre><stock>1222</stock></producto><producto id="2"><nombre>Monitor</nombre><precio>11111</precio><stock>121222</stock></producto></catalogo>`;

console.log(xmlProducto);
// Out:
// <catalogo id="catalogo1"><producto id="1"><precio>11</precio><nombre>Webcam</nombre><stock>1222</stock></producto><producto id="2"><nombre>Monitor</nombre><precio>11111</precio><stock>121222</stock></producto></catalogo>

// %% [markdown]
// <details><summary>Solución Paso 1</summary>
//
// ```js
// const xmlProducto = `
// <producto>
//   <nombre>Teclado Mecánico</nombre>
//   <precio>89.99</precio>
//   <stock>15</stock>
// </producto>`;
// console.log(xmlProducto);
// ```
//
// </details>

// %% [markdown]
// ---
// ## 🥈 Paso 2 — Parsear XML
// Convierte el XML en documento DOM con **DOMParser**:

// %%
// 🧪 Tu código aquí
import { DOMParser } from "https://deno.land/x/deno_dom/deno-dom-wasm.ts";


const document = new DOMParser().parseFromString(xmlProducto, "text/html")

document.querySelectorAll('producto')[1].querySelector('nombre').textContent


document.getElementById("1")
// Out:
// <producto id="1"><precio>11</precio><nombre>Webcam</nombre><stock>1222</stock></producto>

// %% [markdown]
// <details><summary>Solución Paso 2</summary>
//
// ```js
// const parser = new DOMParser();
// const doc = parser.parseFromString(xmlProducto, "application/xml");
// console.log(doc.documentElement.nodeName);
// ```
//
// </details>

// %% [markdown]
// ---
// ## 🥉 Paso 3 — Leer datos del XML
// Extrae y muestra por consola:
// - nombre del producto
// - precio
// - stock

// %%
// 💡 Usa querySelector() y textContent
const producto = document.querySelector('catalogo').children[1]

producto.querySelector('nombre')
producto.querySelector('precio')
producto.querySelector('stock')
// Out:
// <stock>121222</stock>

// %% [markdown]
// <details><summary>Solución Paso 3</summary>
//
// ```js
// const nombre = doc.querySelector("nombre").textContent;
// const precio = doc.querySelector("precio").textContent;
// const stock = doc.querySelector("stock").textContent;
//
// console.log({ nombre, precio, stock });
// ```
//
// </details>

// %% [markdown]
// ---
// ## ⭐ Paso 4 — Añadir nueva información
// Edita tu XML y añade:
// - `<categoria>`
// - `<destacado>` con true/false
//
// Luego, vuelve a parsear y mostrar esos valores.

// %%
// ✍️ Tu XML actualizado aquí...

// %% [markdown]
// <details><summary>Solución Paso 4</summary>
//
// ```js
// const xmlProducto = `
// <producto>
//   <nombre>Teclado Mecánico</nombre>
//   <precio>89.99</precio>
//   <stock>15</stock>
//   <categoria>Gaming</categoria>
//   <destacado>true</destacado>
// </producto>`;
//
// const doc2 = parser.parseFromString(xmlProducto, "application/xml");
// console.log(doc2.querySelector("categoria").textContent);
// console.log(doc2.querySelector("destacado").textContent);
// ```
//
// </details>

// %% [markdown]
// ---
// # 🎯 Resultado final
// Has completado:
// ✔ Crear XML bien formado
// ✔ Leerlo con JavaScript
// ✔ Expandirlo con nuevos datos
//
// 📌 Siguiente → **Bloque 04 — XML DTD**
// Aprenderemos a **validar** XML con reglas externas 🧠
